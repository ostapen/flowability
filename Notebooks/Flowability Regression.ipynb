# %% [markdown]
# This notebook was created by Alissa Ostapenko (aostapenko@wpi.edu) for WPI Army Research Laboratory.
# Date: 05/12/2020.

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# # Flowability Regression
# Here you will learn how to run a basic Regression model (predicting specific flowability numbers) using correlation-matrix based feature selection and Decision Trees. This notebook is based off of the Augmented Microtrac Data (with Density, MinSize, and MaxSize), but these columns can be filtered out during the Data Preprocessing phase.

# %%
from DataPreprocessor import DataPreprocessor
from TrainTestPipeline import TrainTestPipeline
import pandas as pd

# %% [markdown]
# ## Data Preprocessing
# Data Preprocessing is done by the *DataPreprocessor* class. It relies on helper functions in the *data_proprocessing.py* file to:
#  - Transform data to make it follow a Gaussian distribution, and z-score normalize the data
#  - Gets the transformed data and labels (saves to an AllData.csv file to speed up processing
#  - Updates flow numbers and flow classes if they change (and updates AllData.csv as necessary)
#  - Computes correlations (linear and nonlinear) between variables, and can visualize these correlations.
#
#
# **New folders/files you should expect after all data preprocessing, if running this notebook for the first time:**
#  **1.**   New *{Material} {SizeRange} Particles_cleaned.csv* files in your original raw data folder which remove micron symbols from the original raw data files from microtrac (Python's CSV reader cannot parse micron symbols!)
#  **2.**   A new folder, *{RawData}\_transformed* with cleaned, Gaussian, standardized data (one csv file for each sample)
#  **3.**   An *AllData.csv* file with transformed data for all samples
#  **4.**  A *nonlinear_correlation.pkl* file if using MIC-based correlation

# %% [markdown]
# ### Step 1: Initialize a DataPreprocessor Object
#
#
# Specify the:
#  - **Data Folder** with raw, unprocessed CSV files of samples data (e.g., Ti-Nb-Zr (0-63)
#      Particles.csv is in here)
#  - **Flow Values Excel Sheet** with the target flow values and target flow classes.
#  This also includes the Augmented Density (AugDensity) that the materials science team provided for each sample.
#
#
# **IMPORTANT:**
# * In the Flow Values Excel sheet, do **not** type outside of the colored rows, especially in rows below the data. If adding more data, make sure to follow the same format as in the sheet.
# * Make sure the names of your samples, and size ranges of the samples, match **exactly** with how they are named in each raw Excel data sheet in your data folder.

# %%
data_folder = '../RawData'
flow_values_excel = '../TrueFlowValues_.xlsx'
dp = DataPreprocessor(data_folder, flow_values_excel)

# %% [markdown]
# ### Step 2: Prepare the Data
# Files/folders \#1-3 above will be created in this step.
#
# Use the *prepare_df()* method to create files/folders \#1-3, if they have not been created already.
#
# *Note: This may take a few minutes the first time you run it.*

# %%
success = dp.prepare_df()
assert success

# %% [markdown]
# ### Step 3: Feature Selection with a Correlation Matrix
# ```method```  Specify the **method** ('pearson' or 'mic') to run linear or nonlinear correlation, respectively. Default is 'pearson'.
# ```threshold```  Specify a **threshold** (default is 0.8).
# ```heldout_cols```  Specify parameter names you want to **hold out** (to use all parameters, do not specify anything).
#
# *For example, if you want to ignore the augmented features Density, MinSize, and MaxSize, you will do:*
# ```
# heldout_cols = ['Density', 'MinSize', 'MaxSize']
# ```
#
# This step returns a **numpy matrix of the data (X-values)**, as well as a **list of the uncorrelated columns** kept for prediction. **File \#4** will be created if you run 'mic' correlation.
#
# *Note: Running 'mic' correlation may take a few minutes the first time you run it.*

# %%
# Pearson-correlation, full dataset with augmented features
x_filt, columns = dp.get_feature_selection_x(method='pearson', threshold = 0.8, 
                                            heldout_cols = None)
# Out:
# Feature columns used: ['Da', 'Sphericity', 'Ellipse Ratio', 'Concavity', 'Convexity', 'Extent', 'Transparency', 'Curvature', 'L/W Ratio', 'Fiber Length', 'MinSize', 'Density']

# %%
# MIC correlation, full dataset with augmented features 
x_filt_mic, columns_mic = dp.get_feature_selection_x(method='mic', threshold = 0.8, 
                                            heldout_cols = None)
# Out:
# Feature columns used: ['Da', 'Sphericity', 'Compactness', 'Ellipse Ratio', 'Solidity', 'Convexity', 'Extent', 'Transparency', 'Curvature', 'MaxSize']

# %% [markdown]
# #### Optional: Steps to visualize the linear (and nonlinear) correlation matrices:
# We can use the *DataPreprocessor*'s ```visualize_correlation(...)``` function to save the Pearson (or MIC) based correlation matrices to a .pdf.
#
# Specify the following parameters:
# * ```output_file``` Specify a **.pdf** filename to save your results to.
# * ```method``` Specify the method (either *'pearson'* or *'mic'*) (default: 'pearson').
# * ```threshold``` Specify the threshold (default: 0.8).
#
# If you run the cell below, you should see 2 new *.pdf* files:
# * *PearsonCorrelation_for_Augmented_Data.pdf*
# * *MICCorrelation_for_Augmented_Data.pdf*

# %%
# Pearson correlation with a threshold of 0.8
dp.visualize_correlation(output_file = 'PearsonCorrelation_for_Augmented_Data.pdf')
# MIC-correlation with a threshold of 0.8
dp.visualize_correlation(output_file = 'MICCorrelation_for_Augmented_Data.pdf', 
                        method = 'mic', threshold = 0.8)

# %% [markdown]
# ### Step 4: Prepare the Processed Data for Training and Testing
# Use the *DataPreprocessor* to grab the:
# * **Regression Target Values**
# * **List of Sample Names** corresponding to each row of the X-data (*x_filt* and *x_filt_mic* above).
#
# Each sample name is a material and size range.

# %%
y_regr = dp.get_regression_y()
all_samples = dp.get_samples()

# %% [markdown]
# ## Training and Testing
# Model training and testing is done by the *TrainTestPipeline* class. It relies on helper functions in the *training_utils.py* and *test_utils.py* files to:
#  - Split the data into training and test sets (5 samples are used for train, 3 are held out)
#  - Train a (DecisionTreeRegressor) model and test it
#  - Visualize the model test performance and save it to a .pdf file
#  - Visualize the internals of the trained DecisionTreeRegressor, save them to a .png file
#  - Save feature importance rankings to a .csv file

# %% [markdown]
# ### Step 5: Initialize a TrainTestPipeline
# A TrainTestPipeline comprises of 4-5 parameters:
# ```x_data``` Input the **X-data object** (*x_filt* or *x_filt_mic*).
# ```y_data```Input the **Regression target values** (*y_reg*).
# ```all_samples```Input the **List of Sample Names** (*all_samples*).
# ```model_name```Specify the **model type** ("DecisionTreeRegressor").
# * See the OneDrive folder for a full list of supported models.
#
# ```heldout_samples```  Specify a list of **held-out test samples** (optional).
# In this example, we will use our best train set to train our DecisionTree. The heldout samples are:
# * Ti-Nb (64-150)
# * SS-17-4 (64-150)
# * Inconel 718 (0-63)
#
#
# *By default, ```heldout_samples``` is 'random', meaning that 3 random samples from the 8 samples will be selected for testing.*

# %%
# DecisionTreeRegressor trained on the best train set for augmented data 
# filtered by Pearson correlation
pipeline = TrainTestPipeline(x_data = x_filt, y_data = y_regr, all_samples = all_samples, 
                             model_name = 'DecisionTreeRegressor', 
                             heldout_samples = ['Ti-Nb (64-150)', 'SS-17-4 (64-150)', 
                                                'Inconel 718 (0-63)'])

# %% [markdown]
# ### Step 6: Split Data, Train, and Test a Model
# To train our DecisionTreeRegressor on the Pearson correlation matrix filtered features (Density, MinSize, MaxSize are included) we will use:
# ```
# do_train_test(...)
# ```
#
# We will use Leave One Out cross-validation to test our cross-validation accuracy as we learn from the 5 train samples.
#
# LOOCV runs for 5 rounds; each train sample has a chance to be a test sample. The final model is trained on all 5 samples.
#
# With ```cv = False```, we directly train on the 5 samples without looking at cross-validation scores.

# %%
tr_test_ = pipeline.do_train_test(cv = True)
# Out:
# Train Set Proportion: 0.774227
# Test Set Proportion: 0.225773
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 19.50
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Average Validation Score: 21.95
# Test RMSE 0.651407

# %% [markdown]
# ### Step 7: Visualizing Model Performance, Tree Structure, and Feature Importances
# We can save a .pdf visualizing our model's predictions on the heldout test data above:
#
#
# Our Pipeline has a built-in function ```visualize_performance(...)``` for visualizing test performance.

# %% [markdown]
# #### Steps to visualize our test performance:
# 1. ```model``` Get the trained model from our *tr_test_* object above.
# 2. ```train_test_split``` Get the data_split used for training and test, again from *tr_test_* above.
# 2. ```output_file``` Specify a **.pdf** filename to which the pdf of the test performance will be saved.

# %%
#visualize results
model_ = tr_test_['model']
data_split = tr_test_['train_test_split']
pipeline.visualize_performance(model = model_, train_test_split = data_split, 
                               output_file = 'DTViz_Pearson_WithAugmentedData.pdf')

# %% [markdown]
# Check your files. There should now be a *DTViz_Pearson_WithAugmentedData.pdf* saved visualizing the predictions (via markers) versus true mean flow values (dashed-lines). Each sample is color-coded.

# %% [markdown]
# #### Steps to visualize the internals of our tree, and see feature importance rankings:
# We will use a function called ```trained_tree_to_png(...)```. It requires the following:
# 1. ```model``` Get the trained model from our *tr_test_* object above.
# 2. ```feature_names``` List of names of the *columns* we used to train our model. We got these columns after running **Step 2**.
# 3. ```all_y_data``` Array of all of our target flowability values (the *y_regr* object).
# 2. ```outfile_name``` Specify a **.png** filename to which to save the tree to.
#
# In this function, the DecisionTree's feature importance rankings are saved to a csv file named
#
# ```outfile_name``` *\_feature\_importances.csv*

# %%
pipeline.trained_tree_to_png(model_, feature_names=columns, 
                             all_y_data = y_regr, 
                             outfile_name = 'BestTrainSetTree_WithAugmentedData.png')
# Out:
# Feature Importances
#      feature_name     score
# 11        Density  0.987259
# 10        MinSize  0.012741
# 0              Da  0.000000
# 1      Sphericity  0.000000
# 2   Ellipse Ratio  0.000000
# 3       Concavity  0.000000
# 4       Convexity  0.000000
# 5          Extent  0.000000
# 6    Transparency  0.000000
# 7       Curvature  0.000000
# 8       L/W Ratio  0.000000
# 9    Fiber Length  0.000000

# %% [markdown]
# Check your files. There should now be a *BestTrainSetTree_WithAugmentedData.png* saved visualizing the internals of each tree. There should also be a *BestTrainSetTree_WithAugmentedData_feature_importances.csv* file with feature importances, as printed in when running the cell above.

# %%
features_ = pd.read_csv('BestTrainSetTree_WithAugmentedData_feature_importances.csv')
features_.head(10)
# Out:
#     feature_name     score
# 0        Density  0.987259
# 1        MinSize  0.012741
# 2             Da  0.000000
# 3     Sphericity  0.000000
# 4  Ellipse Ratio  0.000000
# 5      Concavity  0.000000
# 6      Convexity  0.000000
# 7         Extent  0.000000
# 8   Transparency  0.000000
# 9      Curvature  0.000000

# %% [markdown]
# ## Finding the Best Train/Test Set
# Use the TrainTestPipeline's ```exhaustive_train(...)``` method to run all 56 combinations of train/test set ups.
# Specify an ```outfile_name```, a *.csv* file to which to save test results. There will be 56 rows; the 3 samples held out for testing will be indicated in each row as well as the RMSE achieved by the model for that train-test split.
#
# After running this, you should see a new *ExhaustiveTrainTest_AugmentedData.csv* file.

# %%
pipeline.exhaustive_train(outfile_name = 'ExhaustiveTrainTest_AugmentedData.csv')
# Out:
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)'], 1 of 56
# Train Set Proportion: 0.384111
# Test Set Proportion: 0.615889
# Train Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)']
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Average Validation Score: 7.07
# Test RMSE 5.074723
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'Ti-Nb (0-63)'], 2 of 56
# Train Set Proportion: 0.283144
# Test Set Proportion: 0.716856
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 1.94
# Average Validation Score: 12.17
# Test RMSE 4.592255
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'SS-17-4 (64-150)'], 3 of 56
# Train Set Proportion: 0.528944
# Test Set Proportion: 0.471056
# Train Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 12.01
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Average Validation Score: 7.67
# Test RMSE 14.327451
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'Ti-Nb-Zr (64-150)'], 4 of 56
# Train Set Proportion: 0.526921
# Test Set Proportion: 0.473079
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Average Validation Score: 1.30
# Test RMSE 23.063503
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 5 of 56
# Train Set Proportion: 0.531890
# Test Set Proportion: 0.468110
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 7.22
# Test RMSE 5.612083
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (0-63)', 'Ti-Nb (64-150)'], 6 of 56
# Train Set Proportion: 0.535442
# Test Set Proportion: 0.464558
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.55
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 11.54
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 11.54
# Average Validation Score: 11.58
# Test RMSE 5.626094
# Combo ['SS-17-4 (10-45)', 'Inconel 718 (0-63)', 'Ti-Nb (0-63)'], 7 of 56
# Train Set Proportion: 0.346378
# Test Set Proportion: 0.653622
# Train Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)']
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.48
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Average Validation Score: 11.74
# Test RMSE 20.251038
# Combo ['SS-17-4 (10-45)', 'Inconel 718 (0-63)', 'SS-17-4 (64-150)'], 8 of 56
# Train Set Proportion: 0.592178
# Test Set Proportion: 0.407822
# Train Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)']
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Training on ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Average Validation Score: 3.46
# Test RMSE 19.164999
# Combo ['SS-17-4 (10-45)', 'Inconel 718 (0-63)', 'Ti-Nb-Zr (64-150)'], 9 of 56
# Train Set Proportion: 0.590155
# Test Set Proportion: 0.409845
# Train Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 17.93
# Average Validation Score: 16.38
# Test RMSE 2.754661
# Combo ['SS-17-4 (10-45)', 'Inconel 718 (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 10 of 56
# Train Set Proportion: 0.595124
# Test Set Proportion: 0.404876
# Train Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 11.43
# Test RMSE 19.046561
# Combo ['SS-17-4 (10-45)', 'Inconel 718 (0-63)', 'Ti-Nb (64-150)'], 11 of 56
# Train Set Proportion: 0.598676
# Test Set Proportion: 0.401324
# Train Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 10.07
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 16.84
# Test RMSE 19.128154
# Combo ['SS-17-4 (10-45)', 'Ti-Nb (0-63)', 'SS-17-4 (64-150)'], 12 of 56
# Train Set Proportion: 0.491211
# Test Set Proportion: 0.508789
# Train Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.48
# Average Validation Score: 16.10
# Test RMSE 22.908542
# Combo ['SS-17-4 (10-45)', 'Ti-Nb (0-63)', 'Ti-Nb-Zr (64-150)'], 13 of 56
# Train Set Proportion: 0.489187
# Test Set Proportion: 0.510813
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.59
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Average Validation Score: 17.00
# Test RMSE 22.940863
# Combo ['SS-17-4 (10-45)', 'Ti-Nb (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 14 of 56
# Train Set Proportion: 0.494156
# Test Set Proportion: 0.505844
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 11.07
# Test RMSE 22.972327
# Combo ['SS-17-4 (10-45)', 'Ti-Nb (0-63)', 'Ti-Nb (64-150)'], 15 of 56
# Train Set Proportion: 0.497709
# Test Set Proportion: 0.502291
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.74
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Average Validation Score: 15.92
# Test RMSE 24.184208
# Combo ['SS-17-4 (10-45)', 'SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)'], 16 of 56
# Train Set Proportion: 0.734988
# Test Set Proportion: 0.265012
# Train Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.16
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Average Validation Score: 16.77
# Test RMSE 2.790154
# Combo ['SS-17-4 (10-45)', 'SS-17-4 (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 17 of 56
# Train Set Proportion: 0.739957
# Test Set Proportion: 0.260043
# Train Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 20.96
# Training on ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Average Validation Score: 19.95
# Test RMSE 0.817116
# Combo ['SS-17-4 (10-45)', 'SS-17-4 (64-150)', 'Ti-Nb (64-150)'], 18 of 56
# Train Set Proportion: 0.743509
# Test Set Proportion: 0.256491
# Train Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)']
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 19.50
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Average Validation Score: 19.71
# Test RMSE 0.725170
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 19 of 56
# Train Set Proportion: 0.737933
# Test Set Proportion: 0.262067
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 27.91
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Average Validation Score: 22.46
# Test RMSE 2.757332
# Combo ['SS-17-4 (10-45)', 'Ti-Nb-Zr (64-150)', 'Ti-Nb (64-150)'], 20 of 56
# Train Set Proportion: 0.741486
# Test Set Proportion: 0.258514
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 26.37
# Average Validation Score: 18.62
# Test RMSE 2.749088
# Combo ['SS-17-4 (10-45)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 21 of 56
# Train Set Proportion: 0.746455
# Test Set Proportion: 0.253545
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)']
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.94
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Average Validation Score: 13.79
# Test RMSE 8.868487
# Combo ['Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)', 'Ti-Nb (0-63)'], 22 of 56
# Train Set Proportion: 0.313861
# Test Set Proportion: 0.686139
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 12.10
# Test RMSE 4.629980
# Combo ['Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)', 'SS-17-4 (64-150)'], 23 of 56
# Train Set Proportion: 0.559662
# Test Set Proportion: 0.440338
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 11.67
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 12.31
# Test RMSE 14.570455
# Combo ['Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)', 'Ti-Nb-Zr (64-150)'], 24 of 56
# Train Set Proportion: 0.557638
# Test Set Proportion: 0.442362
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 13.65
# Average Validation Score: 3.86
# Test RMSE 23.850645
# Combo ['Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 25 of 56
# Train Set Proportion: 0.562607
# Test Set Proportion: 0.437393
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Average Validation Score: 11.86
# Test RMSE 5.805089
# Combo ['Ti-Nb-Zr (0-63)', 'Inconel 718 (0-63)', 'Ti-Nb (64-150)'], 26 of 56
# Train Set Proportion: 0.566160
# Test Set Proportion: 0.433840
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 23.55
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 10.07
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 9.30
# Test RMSE 24.945978
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb (0-63)', 'SS-17-4 (64-150)'], 27 of 56
# Train Set Proportion: 0.458694
# Test Set Proportion: 0.541306
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 9.91
# Test RMSE 13.364351
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb (0-63)', 'Ti-Nb-Zr (64-150)'], 28 of 56
# Train Set Proportion: 0.456671
# Test Set Proportion: 0.543329
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)']
# Test Set Samples: ['Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 1.40
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 1.02
# Test RMSE 21.630707
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 29 of 56
# Train Set Proportion: 0.461639
# Test Set Proportion: 0.538361
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 11.64
# Test RMSE 13.198187
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb (0-63)', 'Ti-Nb (64-150)'], 30 of 56
# Train Set Proportion: 0.465192
# Test Set Proportion: 0.534808
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 10.31
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 22.32
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 22.32
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Average Validation Score: 13.07
# Test RMSE 16.355090
# Combo ['Ti-Nb-Zr (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)'], 31 of 56
# Train Set Proportion: 0.702471
# Test Set Proportion: 0.297529
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Average Validation Score: 0.45
# Test RMSE 29.085143
# Combo ['Ti-Nb-Zr (0-63)', 'SS-17-4 (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 32 of 56
# Train Set Proportion: 0.707440
# Test Set Proportion: 0.292560
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 4.95
# Test RMSE 18.181591
# Combo ['Ti-Nb-Zr (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb (64-150)'], 33 of 56
# Train Set Proportion: 0.710993
# Test Set Proportion: 0.289007
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.55
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 11.54
# Average Validation Score: 7.58
# Test RMSE 18.289334
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 34 of 56
# Train Set Proportion: 0.705417
# Test Set Proportion: 0.294583
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 0.17
# Average Validation Score: 0.53
# Test RMSE 29.228139
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-Nb (64-150)'], 35 of 56
# Train Set Proportion: 0.708969
# Test Set Proportion: 0.291031
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)']
# Test Set Samples: ['Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 11.54
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 1.23
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Average Validation Score: 3.19
# Test RMSE 29.388803
# Combo ['Ti-Nb-Zr (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 36 of 56
# Train Set Proportion: 0.713938
# Test Set Proportion: 0.286062
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 23.55
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 11.54
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 10.07
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.55
# Average Validation Score: 13.81
# Test RMSE 7.173357
# Combo ['Inconel 718 (0-63)', 'Ti-Nb (0-63)', 'SS-17-4 (64-150)'], 37 of 56
# Train Set Proportion: 0.521928
# Test Set Proportion: 0.478072
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.48
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.40
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Average Validation Score: 15.96
# Test RMSE 23.631022
# Combo ['Inconel 718 (0-63)', 'Ti-Nb (0-63)', 'Ti-Nb-Zr (64-150)'], 38 of 56
# Train Set Proportion: 0.519904
# Test Set Proportion: 0.480096
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.38
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Average Validation Score: 18.99
# Test RMSE 26.516617
# Combo ['Inconel 718 (0-63)', 'Ti-Nb (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 39 of 56
# Train Set Proportion: 0.524873
# Test Set Proportion: 0.475127
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 11.70
# Test RMSE 23.703122
# Combo ['Inconel 718 (0-63)', 'Ti-Nb (0-63)', 'Ti-Nb (64-150)'], 40 of 56
# Train Set Proportion: 0.528426
# Test Set Proportion: 0.471574
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.93
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.39
# Average Validation Score: 17.86
# Test RMSE 24.959277
# Combo ['Inconel 718 (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)'], 41 of 56
# Train Set Proportion: 0.765705
# Test Set Proportion: 0.234295
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 1.23
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 0.17
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Average Validation Score: 16.70
# Test RMSE 2.939185
# Combo ['Inconel 718 (0-63)', 'SS-17-4 (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 42 of 56
# Train Set Proportion: 0.770674
# Test Set Proportion: 0.229326
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.15
# Training on ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 20.96
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.53
# Average Validation Score: 19.81
# Test RMSE 0.765967
# Combo ['Inconel 718 (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb (64-150)'], 43 of 56
# Train Set Proportion: 0.774227
# Test Set Proportion: 0.225773
# Train Set Samples: ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 19.50
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 11.67
# Training on ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Average Validation Score: 22.71
# Test RMSE 0.651407
# Combo ['Inconel 718 (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 44 of 56
# Train Set Proportion: 0.768651
# Test Set Proportion: 0.231349
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 27.91
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Average Validation Score: 18.79
# Test RMSE 17.633283
# Combo ['Inconel 718 (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-Nb (64-150)'], 45 of 56
# Train Set Proportion: 0.772203
# Test Set Proportion: 0.227797
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 26.37
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Average Validation Score: 22.07
# Test RMSE 17.765465
# Combo ['Inconel 718 (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 46 of 56
# Train Set Proportion: 0.777172
# Test Set Proportion: 0.222828
# Train Set Samples: ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 19.53
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Average Validation Score: 18.37
# Test RMSE 9.459166
# Combo ['Ti-Nb (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)'], 47 of 56
# Train Set Proportion: 0.664738
# Test Set Proportion: 0.335262
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.59
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Average Validation Score: 22.44
# Test RMSE 28.319716
# Combo ['Ti-Nb (0-63)', 'SS-17-4 (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 48 of 56
# Train Set Proportion: 0.669706
# Test Set Proportion: 0.330294
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 8.67
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 23.72
# Average Validation Score: 10.59
# Test RMSE 28.431788
# Combo ['Ti-Nb (0-63)', 'SS-17-4 (64-150)', 'Ti-Nb (64-150)'], 49 of 56
# Train Set Proportion: 0.673259
# Test Set Proportion: 0.326741
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 13.79
# Test RMSE 29.987836
# Combo ['Ti-Nb (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 50 of 56
# Train Set Proportion: 0.667683
# Test Set Proportion: 0.332317
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 31.59
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.59
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 13.65
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 19.41
# Test RMSE 28.443356
# Combo ['Ti-Nb (0-63)', 'Ti-Nb-Zr (64-150)', 'Ti-Nb (64-150)'], 51 of 56
# Train Set Proportion: 0.671235
# Test Set Proportion: 0.328765
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 30.19
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-5Al-5V-5Mo-3Cr (0-75)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 30.19
# Average Validation Score: 12.53
# Test RMSE 29.997678
# Combo ['Ti-Nb (0-63)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 52 of 56
# Train Set Proportion: 0.676204
# Test Set Proportion: 0.323796
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 7.87
# Average Validation Score: 3.60
# Test RMSE 30.838531
# Combo ['SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)'], 53 of 56
# Train Set Proportion: 0.913484
# Test Set Proportion: 0.086516
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb-Zr (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (64-150)
# RMSE Validation: 27.91
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Average Validation Score: 18.29
# Test RMSE 19.053701
# Combo ['SS-17-4 (64-150)', 'Ti-Nb-Zr (64-150)', 'Ti-Nb (64-150)'], 54 of 56
# Train Set Proportion: 0.917036
# Test Set Proportion: 0.082964
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-5Al-5V-5Mo-3Cr (0-75)
# RMSE Validation: 26.37
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 17.98
# Test RMSE 11.917690
# Combo ['SS-17-4 (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 55 of 56
# Train Set Proportion: 0.922005
# Test Set Proportion: 0.077995
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Test Set Samples: ['SS-17-4 (64-150)' 'Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)']
# Training on ['SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 19.88
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb-Zr (0-63)'
#  'Ti-Nb-Zr (64-150)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb-Zr (64-150)
# RMSE Validation: 7.87
# Training on ['Inconel 718 (0-63)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)' 'Ti-Nb-Zr (64-150)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 11.97
# Test RMSE 16.010059
# Combo ['Ti-Nb-Zr (64-150)', 'Ti-5Al-5V-5Mo-3Cr (0-75)', 'Ti-Nb (64-150)'], 56 of 56
# Train Set Proportion: 0.919982
# Test Set Proportion: 0.080018
# Train Set Samples: ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)'
#  'Ti-Nb-Zr (0-63)']
# Test Set Samples: ['Ti-5Al-5V-5Mo-3Cr (0-75)' 'Ti-Nb (64-150)' 'Ti-Nb-Zr (64-150)']
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)']
# Validating on Ti-Nb-Zr (0-63)
# RMSE Validation: 31.41
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'SS-17-4 (64-150)'
#  'Ti-Nb-Zr (0-63)']
# Validating on Ti-Nb (0-63)
# RMSE Validation: 31.41
# Training on ['SS-17-4 (10-45)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on Inconel 718 (0-63)
# RMSE Validation: 0.34
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (10-45)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (64-150)
# RMSE Validation: 1.60
# Training on ['Inconel 718 (0-63)' 'SS-17-4 (64-150)' 'Ti-Nb (0-63)' 'Ti-Nb-Zr (0-63)']
# Validating on SS-17-4 (10-45)
# RMSE Validation: 0.34
# Average Validation Score: 13.02
# Test RMSE 21.733521

# %%
best_train_sets = pd.read_csv('ExhaustiveTrainTest_AugmentedData.csv')
best_train_sets.head(5)
# Out:
#    TrainProp  TestProp         TestSample1        TestSample2  \
# 0   0.774227  0.225773  Inconel 718 (0-63)   SS-17-4 (64-150)
# 1   0.743509  0.256491     SS-17-4 (10-45)   SS-17-4 (64-150)
# 2   0.770674  0.229326  Inconel 718 (0-63)   SS-17-4 (64-150)
# 3   0.739957  0.260043     SS-17-4 (10-45)   SS-17-4 (64-150)
# 4   0.741486  0.258514     SS-17-4 (10-45)  Ti-Nb-Zr (64-150)
#
#                 TestSample3  CrossVal RMSE  Test RMSE
# 0            Ti-Nb (64-150)      22.705913   0.651407
# 1            Ti-Nb (64-150)      19.707246   0.725170
# 2  Ti-5Al-5V-5Mo-3Cr (0-75)      19.809999   0.765967
# 3  Ti-5Al-5V-5Mo-3Cr (0-75)      19.947333   0.817116
# 4            Ti-Nb (64-150)      18.616880   2.749088
